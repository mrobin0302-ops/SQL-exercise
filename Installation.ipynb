# %%
uv sync
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Using CPython 3.13.2
# Creating virtual environment at: .venv
# Resolved 38 packages in 312ms
# Installed 32 packages in 2.57s
#  + asttokens==3.0.1
#  + colorama==0.4.6
#  + comm==0.2.3
#  + debugpy==1.8.21
#  + decorator==5.3.1
#  + executing==2.2.1
#  + ipykernel==7.3.0
#  + ipython==9.15.0
#  + ipython-pygments-lexers==1.1.1
#  + jedi==0.20.0
#  + jupyter-client==8.9.1
#  + jupyter-core==5.9.1
#  + matplotlib-inline==0.2.2
#  + nest-asyncio2==1.7.2
#  + numpy==2.5.1
#  + packaging==26.2
#  + pandas==3.0.3
#  + parso==0.8.7
#  + platformdirs==4.10.0
#  + prompt-toolkit==3.0.52
#  + psutil==7.2.2
#  + pure-eval==0.2.3
#  + pygments==2.20.0
#  + python-dateutil==2.9.0.post0
#  + pyzmq==27.1.0
#  + six==1.17.0
#  + stack-data==0.6.3
#  + tornado==6.5.7
#  + traitlets==5.15.1
#  + typing-extensions==4.16.0
#  + tzdata==2026.2
#  + wcwidth==0.8.2

# %%
uv add ipykernel
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Resolved 38 packages in 4ms
# Checked 32 packages in 1ms

# %%
uv add pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Resolved 38 packages in 1ms
# Checked 32 packages in 1ms

# %%
# !dir /a
# Out:
#  Le volume dans le lecteur C n’a pas de nom.
#  Le numéro de série du volume est D201-9EEA
#
#  Répertoire de C:\Users\mrobi\Cahier-Vacances-2026
#
# 06/07/2026  16:59    <DIR>          .
# 06/07/2026  16:51    <DIR>          ..
# 06/07/2026  16:32    <DIR>          .git
# 06/07/2026  16:32               197 .gitignore
# 06/07/2026  16:57    <DIR>          .ipynb_checkpoints
# 06/07/2026  16:32                 8 .python-version
# 06/07/2026  16:54    <DIR>          .venv
# 06/07/2026  16:55             5 289 Installation.ipynb
# 06/07/2026  16:53    <DIR>          Projet_01
# 06/07/2026  16:54               191 pyproject.toml
# 06/07/2026  16:32             3 690 README.md
# 06/07/2026  16:59               628 Untitled.ipynb
# 06/07/2026  16:54            79 474 uv.lock
#                7 fichier(s)           89 477 octets
#                6 Rép(s)  193 401 020 416 octets libres

# %%
# !.venv\Scripts\python -m ipykernel install --user --name=cahier-vacances-2026 --display-name="Python (Cahier Vacances 2026)"
# Out:
# Installed kernelspec cahier-vacances-2026 in C:\Users\mrobi\AppData\Roaming\jupyter\kernels\cahier-vacances-2026
