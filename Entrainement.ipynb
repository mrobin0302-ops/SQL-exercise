# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

print("Connexion à la base établie !")
# Out:
# Connexion à la base établie !

# %%
cursor.execute("""
CREATE TABLE passengers (
    id          INTEGER PRIMARY KEY,
    first_name  TEXT NOT NULL,
    last_name   TEXT NOT NULL,
    email       TEXT UNIQUE,
    nationality TEXT
);
""")

# %%
passengers_data = [
    (1, 'Lucas',   'Moreau',   'lucas.moreau@email.fr',    'Française'),
    (2, 'Emma',    'Dubois',   'emma.dubois@email.fr',     'Française'),
    (3, 'Noah',    'Leroy',    'noah.leroy@email.fr',      'Française'),
    (4, 'Sofia',   'Rossi',    'sofia.rossi@email.it',     'Italienne'),
    (5, 'Liam',    'Smith',    'liam.smith@email.uk',      'Britannique'),
    (6, 'Mia',     'Müller',   'mia.muller@email.de',      'Allemande'),
    (7, 'Hugo',    'Bernard',  'hugo.bernard@email.fr',    'Française'),
    (8, 'Camille', 'Thomas',   'camille.thomas@email.fr',  'Française'),
    (9, 'Alice',   'Martin',   'alice.martin@email.fr',    'Française'),
    (10,'Carlos',  'Garcia',   'carlos.garcia@email.es',   'Espagnole'),
    (11,'Jade',    'Petit',    'jade.petit@email.fr',      'Française'),
    (12,'Omar',    'Hassan',   'omar.hassan@email.ma',     'Marocaine'),
    (13,'Elena',   'Popescu',  'elena.popescu@email.ro',   'Roumaine'),
    (14,'Antoine', 'Garnier',  'antoine.garnier@email.fr', 'Française'),
    (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
]

# %%
cursor.executemany("INSERT INTO passengers VALUES (?,?,?,?,?)", passengers_data)
conn.commit()

cursor.execute("SELECT COUNT(*) FROM passengers")
count = cursor.fetchone()[0]
assert count == 15, f"La table passengers devrait contenir 15 passagers, elle en a {count}"
print(f"Table passengers créée et remplie avec {count} passagers !")
# Out:
# Table passengers créée et remplie avec 15 passagers !

# %%
cursor.execute("""
CREATE TABLE flights ( 
    id INTEGER PRIMARY KEY,
    flight_number TEXT NOT NULL, 
    origin TEXT NOT NULL, 
    destination TEXT NOT NULL,
    departure_time TEXT NOT NULL,
    arrival_time TEXT NOT NULL,
    aircraft TEXT,
    capacity INTEGER,
    price_eur REAL
);
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cursor.execute("""
#       2 CREATE TABLE flights (
#       3     id INTEGER PRIMARY KEY,
#       4     flight_number TEXT NOT NULL,
#
# NameError: name 'cursor' is not defined

# %%
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

print("Connexion à la base établie !")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 conn = sqlite3.connect(":memory:")
#       2 cursor = conn.cursor()
#       3
#       4 print("Connexion à la base établie !")
#
# NameError: name 'sqlite3' is not defined

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

print("Connexion à la base établie !")
# Out:
# Connexion à la base établie !

# %%
cursor.execute("""
CREATE TABLE passengers (
    id          INTEGER PRIMARY KEY,
    first_name  TEXT NOT NULL,
    last_name   TEXT NOT NULL,
    email       TEXT UNIQUE,
    nationality TEXT
);
""")

# %%
passengers_data = [
    (1, 'Lucas',   'Moreau',   'lucas.moreau@email.fr',    'Française'),
    (2, 'Emma',    'Dubois',   'emma.dubois@email.fr',     'Française'),
    (3, 'Noah',    'Leroy',    'noah.leroy@email.fr',      'Française'),
    (4, 'Sofia',   'Rossi',    'sofia.rossi@email.it',     'Italienne'),
    (5, 'Liam',    'Smith',    'liam.smith@email.uk',      'Britannique'),
    (6, 'Mia',     'Müller',   'mia.muller@email.de',      'Allemande'),
    (7, 'Hugo',    'Bernard',  'hugo.bernard@email.fr',    'Française'),
    (8, 'Camille', 'Thomas',   'camille.thomas@email.fr',  'Française'),
    (9, 'Alice',   'Martin',   'alice.martin@email.fr',    'Française'),
    (10,'Carlos',  'Garcia',   'carlos.garcia@email.es',   'Espagnole'),
    (11,'Jade',    'Petit',    'jade.petit@email.fr',      'Française'),
    (12,'Omar',    'Hassan',   'omar.hassan@email.ma',     'Marocaine'),
    (13,'Elena',   'Popescu',  'elena.popescu@email.ro',   'Roumaine'),
    (14,'Antoine', 'Garnier',  'antoine.garnier@email.fr', 'Française'),
    (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
# Out:
#   Cell In[6], line 16
#     (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
#                                                                         ^
# _IncompleteInputError: incomplete input

# %%
passengers_data = [
    (1, 'Lucas',   'Moreau',   'lucas.moreau@email.fr',    'Française'),
    (2, 'Emma',    'Dubois',   'emma.dubois@email.fr',     'Française'),
    (3, 'Noah',    'Leroy',    'noah.leroy@email.fr',      'Française'),
    (4, 'Sofia',   'Rossi',    'sofia.rossi@email.it',     'Italienne'),
    (5, 'Liam',    'Smith',    'liam.smith@email.uk',      'Britannique'),
    (6, 'Mia',     'Müller',   'mia.muller@email.de',      'Allemande'),
    (7, 'Hugo',    'Bernard',  'hugo.bernard@email.fr',    'Française'),
    (8, 'Camille', 'Thomas',   'camille.thomas@email.fr',  'Française'),
    (9, 'Alice',   'Martin',   'alice.martin@email.fr',    'Française'),
    (10,'Carlos',  'Garcia',   'carlos.garcia@email.es',   'Espagnole'),
    (11,'Jade',    'Petit',    'jade.petit@email.fr',      'Française'),
    (12,'Omar',    'Hassan',   'omar.hassan@email.ma',     'Marocaine'),
    (13,'Elena',   'Popescu',  'elena.popescu@email.ro',   'Roumaine'),
    (14,'Antoine', 'Garnier',  'antoine.garnier@email.fr', 'Française'),
    (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
]

# %%
cursor.executemany("INSERT INTO passengers VALUES (?,?,?,?,?)", passengers_data)
conn.commit()

cursor.execute("SELECT COUNT(*) FROM passengers")
count = cursor.fetchone()[0]
assert count == 15, f"La table passengers devrait contenir 15 passagers, elle en a {count}"
print(f"Table passengers créée et remplie avec {count} passagers !")
# Out:
# Table passengers créée et remplie avec 15 passagers !

# %%
cursor.execute("""
CREATE TABLE flights ( 
    id INTEGER PRIMARY KEY,
    flight_number TEXT NOT NULL, 
    origin TEXT NOT NULL, 
    destination TEXT NOT NULL,
    departure_time TEXT NOT NULL,
    arrival_time TEXT NOT NULL,
    aircraft TEXT,
    capacity INTEGER,
    price_eur REAL
);
""")

# %%
flights_data = [
    (1,  'AF1234', 'Nice',      'Paris CDG',    '2026-07-01 07:00', '2026-07-01 08:30', 'Airbus A320', 180, 89.0),
    (2,  'AF1235', 'Paris CDG', 'Nice',          '2026-07-01 19:00', '2026-07-01 20:30', 'Airbus A320', 180, 95.0),
    (3,  'EZ4501', 'Nice',      'Londres',       '2026-07-02 06:30', '2026-07-02 08:15', 'Airbus A319', 156, 120.0),
    (4,  'EZ4502', 'Nice',      'Amsterdam',     '2026-07-02 09:00', '2026-07-02 11:30', 'Airbus A319', 156, 135.0),
    (5,  'VY6010', 'Nice',      'Barcelone',     '2026-07-03 11:00', '2026-07-03 12:45', 'Boeing 737',  189, 78.0),
    (6,  'AF5501', 'Nice',      'New York JFK',  '2026-07-04 13:00', '2026-07-04 22:30', 'Boeing 777',  350, 650.0),
    (7,  'LH2201', 'Nice',      'Francfort',     '2026-07-05 08:00', '2026-07-05 09:45', 'Airbus A320', 180, 112.0),
    (8,  'IB3301', 'Nice',      'Madrid',        '2026-07-05 14:00', '2026-07-05 16:00', 'Boeing 737',  189, 99.0),
    (9,  'AF1236', 'Nice',      'Paris CDG',     '2026-07-06 18:00', '2026-07-06 19:30', 'Airbus A320', 180, 105.0),
    (10, 'U24401', 'Nice',      'Athènes',       '2026-07-07 10:00', '2026-07-07 13:30', 'Boeing 737',  189, 145.0),
    (11, 'FR7701', 'Nice',      'Dublin',        '2026-07-08 07:30', '2026-07-08 10:00', 'Boeing 737',  189, 89.0),
    (12, 'AF1237', 'Paris CDG', 'Nice',          '2026-07-08 20:00', '2026-07-08 21:30', 'Airbus A321', 220, 88.0),
    (13, 'EZ4503', 'Nice',      'Berlin',        '2026-07-09 12:00', '2026-07-09 14:15', 'Airbus A319', 156, 118.0),
    (14, 'AF5502', 'Nice',      'New York JFK',  '2026-07-10 13:00', '2026-07-10 22:30', 'Boeing 777',  350, 680.0),
    (15, 'TK8801', 'Nice',      'Istanbul',      '2026-07-11 09:00', '2026-07-11 12:30', 'Boeing 737',  189, 160.0),
]

# %%
cursor.executemany("INSERT INTO flights VALUES (?,?,?,?,?,?,?,?,?)", flights_data)
conn.commit()

cursor.execute("PRAGMA table_info(flights)")
columns = cursor.fetchall()
schema = {col[1]: col[2] for col in columns}
expected_schema = {
    'id': 'INTEGER', 'flight_number': 'TEXT', 'origin': 'TEXT', 'destination': 'TEXT',
    'departure_time': 'TEXT', 'arrival_time': 'TEXT', 'aircraft': 'TEXT',
    'capacity': 'INTEGER', 'price_eur': 'REAL',
}
assert schema == expected_schema, f"Le schéma ne correspond pas. Attendu : {expected_schema}, obtenu : {schema}"

not_null_columns = {col[1] for col in columns if col[3] == 1}
expected_not_null = {'flight_number', 'origin', 'destination', 'departure_time', 'arrival_time'}
assert not_null_columns == expected_not_null, \
    f"Les colonnes NOT NULL attendues sont {expected_not_null}, tu as : {not_null_columns}"

cursor.execute("SELECT COUNT(*) FROM flights")
count = cursor.fetchone()[0]
assert count == 15, f"La table flights devrait contenir 15 vols, elle en a {count}"
print(f"Table flights créée et remplie avec {count} vols, exercice validé !")
# Out:
# Table flights créée et remplie avec 15 vols, exercice validé !

# %%
cursor.execute("""
CREAT TABLE bookings (
    id INTEGER PRIMARY KEY,
    passenger_id INTEGER REFERENCES passengers(id),
    flight_id INTEGER REFERENCES flights(id)
    booking_date TEXT,
    seat_class TEXT CHECK parmi 'economy', 'business', 'first',
    seat_number TEXT,
    status TEXT CHECK parmi 'confirmed', 'cancelled', 'pending'
);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 cursor.execute("""
#       2 CREAT TABLE bookings (
#       3     id INTEGER PRIMARY KEY,
#       4     passenger_id INTEGER REFERENCES passengers(id),
#
# OperationalError: near "CREAT": syntax error

# %%
cursor.execute("""
CREATE TABLE bookings (
    id INTEGER PRIMARY KEY,
    passenger_id INTEGER REFERENCES passengers(id),
    flight_id INTEGER REFERENCES flights(id)
    booking_date TEXT,
    seat_class TEXT CHECK parmi 'economy', 'business', 'first',
    seat_number TEXT,
    status TEXT CHECK parmi 'confirmed', 'cancelled', 'pending'
);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cursor.execute("""
#       2 CREATE TABLE bookings (
#       3     id INTEGER PRIMARY KEY,
#       4     passenger_id INTEGER REFERENCES passengers(id),
#
# OperationalError: near "booking_date": syntax error

# %%
cursor.execute("""
CREATE TABLE bookings (
    id INTEGER PRIMARY KEY,
    passenger_id INTEGER REFERENCES passengers(id),
    flight_id INTEGER REFERENCES flights(id),
    booking_date TEXT,
    seat_class TEXT CHECK parmi 'economy', 'business', 'first',
    seat_number TEXT,
    status TEXT CHECK parmi 'confirmed', 'cancelled', 'pending'
);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cursor.execute("""
#       2 CREATE TABLE bookings (
#       3     id INTEGER PRIMARY KEY,
#       4     passenger_id INTEGER REFERENCES passengers(id),
#
# OperationalError: near "parmi": syntax error

# %%
cursor.execute("""
CREATE TABLE bookings (
    id INTEGER PRIMARY KEY,
    passenger_id INTEGER REFERENCES passengers(id),
    flight_id INTEGER REFERENCES flights(id),
    booking_date TEXT,
    seat_class TEXT CHECK (seat_class IN ('economy', 'business', 'first')),
    seat_number TEXT,
    status TEXT CHECK (status IN ('confirmed', 'cancelled', 'pending'))
);
""")

# %%
bookings_data = [
    (1,  1,  1,  '2026-06-01', 'economy',  '14A', 'confirmed'),
    (2,  2,  1,  '2026-06-02', 'business', '2C',  'confirmed'),
    (4,  4,  5,  '2026-06-05', 'economy',  '18C', 'confirmed'),
    (5,  5,  3,  '2026-06-06', 'business', '1A',  'confirmed'),
    (6,  6,  7,  '2026-06-07', 'economy',  '31D', 'confirmed'),
    (7,  7,  6,  '2026-06-08', 'first',    '1A',  'confirmed'),
    (8,  8,  6,  '2026-06-09', 'business', '3B',  'confirmed'),
    (9,  9,  9,  '2026-06-10', 'economy',  '25A', 'confirmed'),
    (10, 10, 5,  '2026-06-11', 'economy',  '17B', 'cancelled'),
    (11, 11, 10, '2026-06-12', 'economy',  '8C',  'confirmed'),
    (12, 12, 15, '2026-06-13', 'economy',  '11A', 'confirmed'),
    (13, 13, 4,  '2026-06-14', 'economy',  '29B', 'pending'),
    (14, 14, 2,  '2026-06-15', 'business', '4A',  'confirmed'),
    (15, 15, 6,  '2026-06-16', 'first',    '2A',  'confirmed'),
    (16, 1,  9,  '2026-06-17', 'economy',  '33C', 'confirmed'),
    (17, 2,  10, '2026-06-18', 'economy',  '15A', 'cancelled'),
    (18, 5,  6,  '2026-06-19', 'business', '5B',  'confirmed'),
    (19, 7,  14, '2026-06-20', 'first',    '1B',  'confirmed'),
    (20, 9,  11, '2026-06-21', 'economy',  '22D', 'confirmed'),
]

# %%
cursor.executemany("INSERT INTO bookings VALUES (?,?,?,?,?,?,?)", bookings_data)
conn.commit()

cursor.execute("PRAGMA table_info(bookings)")
schema = {col[1]: col[2] for col in cursor.fetchall()}
expected_schema = {
    'id': 'INTEGER', 'passenger_id': 'INTEGER', 'flight_id': 'INTEGER',
    'booking_date': 'TEXT', 'seat_class': 'TEXT', 'seat_number': 'TEXT', 'status': 'TEXT',
}
assert schema == expected_schema, f"Le schéma ne correspond pas. Attendu : {expected_schema}, obtenu : {schema}"

try:
    cursor.execute("INSERT INTO bookings VALUES (999, 1, 1, '2026-06-30', 'premium', '1A', 'confirmed')")
    raise AssertionError("La contrainte CHECK sur seat_class ne fonctionne pas : 'premium' a été accepté")
except sqlite3.IntegrityError:
    pass

cursor.execute("SELECT COUNT(*) FROM bookings")
count = cursor.fetchone()[0]
assert count == 19, f"La table bookings devrait contenir 19 réservations, elle en a {count}"

print("Base de données complète, exercice validé !")
print(f"  {len(passengers_data)} passagers")
print(f"  {len(flights_data)} vols")
print(f"  {len(bookings_data)} réservations")
# Out:
# Base de données complète, exercice validé !
#   15 passagers
#   15 vols
#   19 réservations

# %%
def query(sql):
    """Execute a SQL query and return the result as a pandas DataFrame."""
    return pd.read_sql_query(sql, conn)

print("=== PASSENGERS ===")
display(query("SELECT * FROM passengers LIMIT 5"))
print("=== FLIGHTS ===")
display(query("SELECT * FROM flights LIMIT 5"))
print("=== BOOKINGS ===")
display(query("SELECT * FROM bookings LIMIT 5"))
# Out:
# === PASSENGERS ===
#    id first_name last_name                  email  nationality
# 0   1      Lucas    Moreau  lucas.moreau@email.fr    Française
# 1   2       Emma    Dubois   emma.dubois@email.fr    Française
# 2   3       Noah     Leroy    noah.leroy@email.fr    Française
# 3   4      Sofia     Rossi   sofia.rossi@email.it    Italienne
# 4   5       Liam     Smith    liam.smith@email.uk  Britannique
# === FLIGHTS ===
#    id flight_number     origin destination    departure_time  \
# 0   1        AF1234       Nice   Paris CDG  2026-07-01 07:00
# 1   2        AF1235  Paris CDG        Nice  2026-07-01 19:00
# 2   3        EZ4501       Nice     Londres  2026-07-02 06:30
# 3   4        EZ4502       Nice   Amsterdam  2026-07-02 09:00
# 4   5        VY6010       Nice   Barcelone  2026-07-03 11:00
#
#        arrival_time     aircraft  capacity  price_eur
# 0  2026-07-01 08:30  Airbus A320       180       89.0
# 1  2026-07-01 20:30  Airbus A320       180       95.0
# 2  2026-07-02 08:15  Airbus A319       156      120.0
# 3  2026-07-02 11:30  Airbus A319       156      135.0
# 4  2026-07-03 12:45   Boeing 737       189       78.0
# === BOOKINGS ===
#    id  passenger_id  flight_id booking_date seat_class seat_number     status
# 0   1             1          1   2026-06-01    economy         14A  confirmed
# 1   2             2          1   2026-06-02   business          2C  confirmed
# 2   4             4          5   2026-06-05    economy         18C  confirmed
# 3   5             5          3   2026-06-06   business          1A  confirmed
# 4   6             6          7   2026-06-07    economy         31D  confirmed

# %%
result = query("""
SELECT flight_number, destination, departure_time, price
FROM flights
WHERE origin = 'Nice'
ORDER BY departure_time;
""")

display(result)

assert len(result) == 13, f"Tu devrais avoir 13 vols au départ de Nice, tu en as {len(result)}"
assert list(result.columns) == ['flight_number', 'destination', 'departure_time', 'price_eur'], \
    "Vérifie les colonnes sélectionnées"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: price
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 result = query("""
#       2 SELECT flight_number, destination, departure_time, price
#       3 FROM flights
#       4 WHERE origin = 'Nice'
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT flight_number, destination, departure_time, price
# FROM flights
# WHERE origin = 'Nice'
# ORDER BY departure_time;
# ': no such column: price

# %%
result = query("""
SELECT flight_number, destination, departure_time, price_eur
FROM flights
WHERE origin = 'Nice'
ORDER BY departure_time;
""")

display(result)

assert len(result) == 13, f"Tu devrais avoir 13 vols au départ de Nice, tu en as {len(result)}"
assert list(result.columns) == ['flight_number', 'destination', 'departure_time', 'price_eur'], \
    "Vérifie les colonnes sélectionnées"
print("Exercice validé !")
# Out:
#    flight_number   destination    departure_time  price_eur
# 0         AF1234     Paris CDG  2026-07-01 07:00       89.0
# 1         EZ4501       Londres  2026-07-02 06:30      120.0
# 2         EZ4502     Amsterdam  2026-07-02 09:00      135.0
# 3         VY6010     Barcelone  2026-07-03 11:00       78.0
# 4         AF5501  New York JFK  2026-07-04 13:00      650.0
# 5         LH2201     Francfort  2026-07-05 08:00      112.0
# 6         IB3301        Madrid  2026-07-05 14:00       99.0
# 7         AF1236     Paris CDG  2026-07-06 18:00      105.0
# 8         U24401       Athènes  2026-07-07 10:00      145.0
# 9         FR7701        Dublin  2026-07-08 07:30       89.0
# 10        EZ4503        Berlin  2026-07-09 12:00      118.0
# 11        AF5502  New York JFK  2026-07-10 13:00      680.0
# 12        TK8801      Istanbul  2026-07-11 09:00      160.0
# Exercice validé !

# %%
result = query("""
SELECT flight_number, destintion, price_eur
FROM flights 
WHERE price_eur < 100
ORDER BY price_eur;
""")
display(result)

assert len(result) == 6, f"Tu devrais avoir 6 vols sous 100 euros, tu en as {len(result)}"
assert result['price_eur'].is_monotonic_increasing, "Les résultats doivent être triés par prix croissant"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: destintion
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 result = query("""
#       2 SELECT flight_number, destintion, price_eur
#       3 FROM flights
#       4 WHERE price_eur < 100
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT flight_number, destintion, price_eur
# FROM flights
# WHERE price_eur < 100
# ORDER BY price_eur;
# ': no such column: destintion

# %%
result = query("""
SELECT flight_number, destination, price_eur
FROM flights 
WHERE price_eur < 100
ORDER BY price_eur;
""")
display(result)

assert len(result) == 6, f"Tu devrais avoir 6 vols sous 100 euros, tu en as {len(result)}"
assert result['price_eur'].is_monotonic_increasing, "Les résultats doivent être triés par prix croissant"
print("Exercice validé !")
# Out:
#   flight_number destination  price_eur
# 0        VY6010   Barcelone       78.0
# 1        AF1237        Nice       88.0
# 2        AF1234   Paris CDG       89.0
# 3        FR7701      Dublin       89.0
# 4        AF1235        Nice       95.0
# 5        IB3301      Madrid       99.0
# Exercice validé !

# %%
result = query("""
SELECT * FROM passengers WHERE 'last_name' = 'Tanaka';
""")
display(result)

assert len(result) == 1
assert result.iloc[0]['first_name'] == 'Yako'
print("Exercice validé !")
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, nationality]
# Index: []
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 6
#       2 SELECT * FROM passengers WHERE 'last_name' = 'Tanaka';
#       3 """)
#       4 display(result)
#       5
# ----> 6 assert len(result) == 1
#       7 assert result.iloc[0]['first_name'] == 'Yako'
#       8 print("Exercice validé !")
#
# AssertionError:

# %%
result = query("""
SELECT * FROM passengers WHERE 'last_name' == 'Tanaka';
""")
display(result)

assert len(result) == 1
assert result.iloc[0]['first_name'] == 'Yako'
print("Exercice validé !")
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, nationality]
# Index: []
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[24], line 6
#       2 SELECT * FROM passengers WHERE 'last_name' == 'Tanaka';
#       3 """)
#       4 display(result)
#       5
# ----> 6 assert len(result) == 1
#       7 assert result.iloc[0]['first_name'] == 'Yako'
#       8 print("Exercice validé !")
#
# AssertionError:

# %%
result = query("""
SELECT * FROM passengers WHERE last_name = 'Tanaka';
""")
display(result)

assert len(result) == 1
assert result.iloc[0]['first_name'] == 'Yako'
print("Exercice validé !")
# Out:
#    id first_name last_name                 email nationality
# 0  15       Yako    Tanaka  yuki.tanaka@email.jp   Japonaise
# Exercice validé !

# %%
result = query("""
SELECT status, COUNT(*) AS count
FROM bookings
GROUP BY status
ORDER BY count DESC;
""")
display(result)

assert len(result) == 3, "Il doit y avoir 3 statuts distincts"
confirmed_count = result[result['status'] == 'confirmed']['count'].values[0]
assert confirmed_count == 16, f"Il devrait y avoir 16 réservations confirmées, tu en as {confirmed_count}"
print("Exercice validé !")
# Out:
#       status  count
# 0  confirmed     16
# 1  cancelled      2
# 2    pending      1
# Exercice validé !

# %%
result = query("""
SELECT 
    flights.destination,
    SUM(flights.price_eur) AS total_revenue,
    COUNT(bookings.id) AS nb_bookings
FROM bookings
JOIN flights ON bookings.flight_id 
WHERE bookings.status = 'confirmed'
GROUP BY flights.destination
ORDER BY total_revenue DESC;
""")
display(result)

assert 'destination' in result.columns
assert 'total_revenue' in result.columns
assert result['total_revenue'].is_monotonic_decreasing, "Trie par CA décroissant"
top_dest = result.iloc[0]['destination']
assert top_dest == 'New York JFK', f"La destination avec le plus de CA devrait être New York JFK, pas {top_dest}"
print("Exercice validé !")
# Out:
#      destination  total_revenue  nb_bookings
# 0   New York JFK        21280.0           32
# 1      Paris CDG         3104.0           32
# 2           Nice         2928.0           32
# 3       Istanbul         2560.0           16
# 4        Athènes         2320.0           16
# 5      Amsterdam         2160.0           16
# 6        Londres         1920.0           16
# 7         Berlin         1888.0           16
# 8      Francfort         1792.0           16
# 9         Madrid         1584.0           16
# 10        Dublin         1424.0           16
# 11     Barcelone         1248.0           16
# Exercice validé !

# %%
result = query("""
SELECT 
    f.destination,
    SUM(f.price_eur) AS total_revenue,
    COUNT(b.id) AS nb_bookings
FROM bookings b
JOIN flights f ON b.flight_id = f.id
WHERE b.status = 'confirmed'
GROUP BY f.destination
HAVING COUNT(bookings.id) > 1
ORDER BY total_revenue DESC;
""")
display(result)

assert all(result['nb_bookings'] > 1), "Toutes les destinations affichées doivent avoir plus d'une réservation"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: bookings.id
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     f.destination,
#       4     SUM(f.price_eur) AS total_revenue,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     f.destination,
#     SUM(f.price_eur) AS total_revenue,
#     COUNT(b.id) AS nb_bookings
# FROM bookings b
# JOIN flights f ON b.flight_id = f.id
# WHERE b.status = 'confirmed'
# GROUP BY f.destination
# HAVING COUNT(bookings.id) > 1
# ORDER BY total_revenue DESC;
# ': no such column: bookings.id

# %%
result = query("""
SELECT 
    flights.destination,
    SUM(flights.price_eur) AS total_revenue,
    COUNT(bookings.id) AS nb_bookings
FROM bookings
JOIN flights ON bookings.flight_id 
WHERE bookings.status = 'confirmed'
GROUP BY flights.destination
HAVING COUNT(bookings.id) > 1
ORDER BY total_revenue DESC;
""")
display(result)

assert 'destination' in result.columns
assert 'total_revenue' in result.columns
assert result['total_revenue'].is_monotonic_decreasing, "Trie par CA décroissant"
top_dest = result.iloc[0]['destination']
assert top_dest == 'New York JFK', f"La destination avec le plus de CA devrait être New York JFK, pas {top_dest}"
print("Exercice validé !")
# Out:
#      destination  total_revenue  nb_bookings
# 0   New York JFK        21280.0           32
# 1      Paris CDG         3104.0           32
# 2           Nice         2928.0           32
# 3       Istanbul         2560.0           16
# 4        Athènes         2320.0           16
# 5      Amsterdam         2160.0           16
# 6        Londres         1920.0           16
# 7         Berlin         1888.0           16
# 8      Francfort         1792.0           16
# 9         Madrid         1584.0           16
# 10        Dublin         1424.0           16
# 11     Barcelone         1248.0           16
# Exercice validé !

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number,
FROM passengers
JOIN bookings ON bookings.flight_id AND flights ON flights.id
WHERE booking.status = 'confirmed' AND flights.flights_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: near "AS": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.first_name AS first_name,
#       4     passengers.last name AS last_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.first_name AS first_name,
#     passengers.last name AS last_name,
#     bookings.seat_class AS seat_class,
#     bookings.seat_number AS seat_number,
# FROM passengers
# JOIN bookings ON bookings.flight_id AND flights ON flights.id
# WHERE booking.status = 'confirmed' AND flights.flights_number ='AF5501';
#
# ': near "AS": syntax error

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last_name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number,
FROM passengers
JOIN bookings ON bookings.flight_id AND flights ON flights.id
WHERE booking.status = 'confirmed' AND flights.flights_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: near "FROM": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.first_name AS first_name,
#       4     passengers.last_name AS last_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.first_name AS first_name,
#     passengers.last_name AS last_name,
#     bookings.seat_class AS seat_class,
#     bookings.seat_number AS seat_number,
# FROM passengers
# JOIN bookings ON bookings.flight_id AND flights ON flights.id
# WHERE booking.status = 'confirmed' AND flights.flights_number ='AF5501';
#
# ': near "FROM": syntax error

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last_name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number
FROM passengers
JOIN bookings ON bookings.flight_id AND flights ON flights.id
WHERE booking.status = 'confirmed' AND flights.flights_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: near "ON": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.first_name AS first_name,
#       4     passengers.last_name AS last_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.first_name AS first_name,
#     passengers.last_name AS last_name,
#     bookings.seat_class AS seat_class,
#     bookings.seat_number AS seat_number
# FROM passengers
# JOIN bookings ON bookings.flight_id AND flights ON flights.id
# WHERE booking.status = 'confirmed' AND flights.flights_number ='AF5501';
#
# ': near "ON": syntax error

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last_name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number
FROM passengers
JOIN bookings ON bookings.flight_id 
JOIN flights ON flights.id
WHERE bookings.status = 'confirmed' AND flights.flights_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: flights.flights_number
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.first_name AS first_name,
#       4     passengers.last_name AS last_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.first_name AS first_name,
#     passengers.last_name AS last_name,
#     bookings.seat_class AS seat_class,
#     bookings.seat_number AS seat_number
# FROM passengers
# JOIN bookings ON bookings.flight_id
# JOIN flights ON flights.id
# WHERE bookings.status = 'confirmed' AND flights.flights_number ='AF5501';
#
# ': no such column: flights.flights_number

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last_name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number
FROM passengers
JOIN bookings ON bookings.flight_id 
JOIN flights ON flights.id
WHERE bookings.status = 'confirmed' AND flights.flight_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
#     first_name last_name seat_class seat_number
# 0        Lucas    Moreau   business          2C
# 1        Lucas    Moreau    economy         14A
# 2        Lucas    Moreau   business          4A
# 3        Lucas    Moreau   business          1A
# 4        Lucas    Moreau    economy         18C
# ..         ...       ...        ...         ...
# 235       Yako    Tanaka    economy         33C
# 236       Yako    Tanaka    economy          8C
# 237       Yako    Tanaka    economy         22D
# 238       Yako    Tanaka      first          1B
# 239       Yako    Tanaka    economy         11A
#
# [240 rows x 4 columns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[34], line 15
#      11
#      12 """)
#      13 display(result)
#      14
# ---> 15 assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
#      16 names = set(result['last_name'].values)
#      17 assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
#      18 print("Exercice validé !")
#
# AssertionError: 4 passagers confirmés sur ce vol, tu en as 240

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last_name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number
FROM passengers
JOIN bookings ON passengers.id = bookings.passenger_id
JOIN flights ON ON bookings.flight_id = flights.id
WHERE bookings.status = 'confirmed' AND flights.flight_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: near "ON": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.first_name AS first_name,
#       4     passengers.last_name AS last_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.first_name AS first_name,
#     passengers.last_name AS last_name,
#     bookings.seat_class AS seat_class,
#     bookings.seat_number AS seat_number
# FROM passengers
# JOIN bookings ON passengers.id = bookings.passenger_id
# JOIN flights ON ON bookings.flight_id = flights.id
# WHERE bookings.status = 'confirmed' AND flights.flight_number ='AF5501';
#
# ': near "ON": syntax error

# %%
result = query("""
SELECT 
    passengers.first_name AS first_name,
    passengers.last_name AS last_name,
    bookings.seat_class AS seat_class,
    bookings.seat_number AS seat_number
FROM passengers
JOIN bookings ON passengers.id = bookings.passenger_id
JOIN flights ON bookings.flight_id = flights.id
WHERE bookings.status = 'confirmed' AND flights.flight_number ='AF5501';
    
""")
display(result)

assert len(result) == 4, f"4 passagers confirmés sur ce vol, tu en as {len(result)}"
names = set(result['last_name'].values)
assert names == {'Bernard', 'Thomas', 'Tanaka', 'Smith'}, f"Les passagers attendus sont Garnier, Bernard, Tanaka. Tu as : {names}"
print("Exercice validé !")
# Out:
#   first_name last_name seat_class seat_number
# 0       Hugo   Bernard      first          1A
# 1    Camille    Thomas   business          3B
# 2       Yako    Tanaka      first          2A
# 3       Liam     Smith   business          5B
# Exercice validé !

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name, 
    passengers.first_name AS first_name
FROM passengers
JOIN bookings ON passengers.id = bookings.passenger_id
WHERE bookings.status = 'NULL';
""")
display(result)

assert len(result) == 1, f"Il y a 1 passagers sans réservation, tu en as {len(result)}"
print("Exercice validé !")
# Out:
# Empty DataFrame
# Columns: [last_name, first_name]
# Index: []
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[37], line 11
#       7 WHERE bookings.status = 'NULL';
#       8 """)
#       9 display(result)
#      10
# ---> 11 assert len(result) == 1, f"Il y a 1 passagers sans réservation, tu en as {len(result)}"
#      12 print("Exercice validé !")
#
# AssertionError: Il y a 1 passagers sans réservation, tu en as 0

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name, 
    passengers.first_name AS first_name
FROM passengers
LEFT JOIN bookings ON passengers.id = bookings.passenger_id
WHERE bookings.passenger_id IS NULL;
""")
display(result)

assert len(result) == 1, f"Il y a 1 passager sans réservation, tu en as {len(result)}"
print("Exercice validé !")
# Out:
#   last_name first_name
# 0     Leroy       Noah
# Exercice validé !

# %%
result = query("""
SELECT 
    flight_number, destination, price_eur
FROM flights
WHERE price_eur > (SUM(price_eur)/COUNT(*)
""")
display(result)

avg_price = pd.read_sql_query("SELECT AVG(price_eur) as avg FROM flights", conn)['avg'].values[0]
assert all(result['price_eur'] > avg_price), f"Tous les vols doivent être au-dessus de la moyenne ({avg_price:.2f} euros)"
print(f"Prix moyen : {avg_price:.2f} euros")
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: incomplete input
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     flight_number, destination, price_eur
#       4 FROM flights
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     flight_number, destination, price_eur
# FROM flights
# WHERE price_eur > (SUM(price_eur)/COUNT(*)
# ': incomplete input

# %%
result = query("""
SELECT 
    flight_number, destination, price_eur
FROM flights
WHERE price_eur > (SUM(price_eur)/COUNT(*))
""")
display(result)

avg_price = pd.read_sql_query("SELECT AVG(price_eur) as avg FROM flights", conn)['avg'].values[0]
assert all(result['price_eur'] > avg_price), f"Tous les vols doivent être au-dessus de la moyenne ({avg_price:.2f} euros)"
print(f"Prix moyen : {avg_price:.2f} euros")
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: misuse of aggregate function COUNT()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     flight_number, destination, price_eur
#       4 FROM flights
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     flight_number, destination, price_eur
# FROM flights
# WHERE price_eur > (SUM(price_eur)/COUNT(*))
# ': misuse of aggregate function COUNT()

# %%
result = query("""
SELECT 
    flight_number, destination, price_eur
FROM flights
WHERE price_eur > (SUM(price_eur)/COUNT(flight_number))
""")
display(result)

avg_price = pd.read_sql_query("SELECT AVG(price_eur) as avg FROM flights", conn)['avg'].values[0]
assert all(result['price_eur'] > avg_price), f"Tous les vols doivent être au-dessus de la moyenne ({avg_price:.2f} euros)"
print(f"Prix moyen : {avg_price:.2f} euros")
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: misuse of aggregate function COUNT()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     flight_number, destination, price_eur
#       4 FROM flights
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     flight_number, destination, price_eur
# FROM flights
# WHERE price_eur > (SUM(price_eur)/COUNT(flight_number))
# ': misuse of aggregate function COUNT()

# %%
result = query("""
SELECT 
    flight_number, destination, price_eur
FROM flights
WHERE price_eur > (SELECT AVG(price_eur) FROM flights);
""")
display(result)

avg_price = pd.read_sql_query("SELECT AVG(price_eur) as avg FROM flights", conn)['avg'].values[0]
assert all(result['price_eur'] > avg_price), f"Tous les vols doivent être au-dessus de la moyenne ({avg_price:.2f} euros)"
print(f"Prix moyen : {avg_price:.2f} euros")
print("Exercice validé !")
# Out:
#   flight_number   destination  price_eur
# 0        AF5501  New York JFK      650.0
# 1        AF5502  New York JFK      680.0
# Prix moyen : 184.20 euros
# Exercice validé !

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name,
    passengers.first_name AS first_name,
    COUNT(bookinkgs.passenger_id) AS nb_bookings
FROM passengers
JOIN bookings ON bookings.passenger_id = passengers.passenger_id
WHERE COUNT(bookinkgs.passenger_id) > 1
""")
display(result)

assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
assert all(result['nb_bookings'] >= 2)
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: bookinkgs.passenger_id
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.last_name AS last_name,
#       4     passengers.first_name AS first_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.last_name AS last_name,
#     passengers.first_name AS first_name,
#     COUNT(bookinkgs.passenger_id) AS nb_bookings
# FROM passengers
# JOIN bookings ON bookings.passenger_id = passengers.passenger_id
# WHERE COUNT(bookinkgs.passenger_id) > 1
# ': no such column: bookinkgs.passenger_id

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name,
    passengers.first_name AS first_name,
    COUNT(bookings.passenger_id) AS nb_bookings
FROM passengers
JOIN bookings ON bookings.passenger_id = passengers.passenger_id
WHERE COUNT(bookinkgs.passenger_id) > 1
""")
display(result)

assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
assert all(result['nb_bookings'] >= 2)
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: bookinkgs.passenger_id
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.last_name AS last_name,
#       4     passengers.first_name AS first_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.last_name AS last_name,
#     passengers.first_name AS first_name,
#     COUNT(bookings.passenger_id) AS nb_bookings
# FROM passengers
# JOIN bookings ON bookings.passenger_id = passengers.passenger_id
# WHERE COUNT(bookinkgs.passenger_id) > 1
# ': no such column: bookinkgs.passenger_id

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name,
    passengers.first_name AS first_name,
    COUNT(bookings.passenger_id) AS nb_bookings
FROM passengers
JOIN bookings ON bookings.passenger_id = passengers.passenger_id
WHERE COUNT(bookings.passenger_id) > 1
""")
display(result)

assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
assert all(result['nb_bookings'] >= 2)
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: passengers.passenger_id
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.last_name AS last_name,
#       4     passengers.first_name AS first_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.last_name AS last_name,
#     passengers.first_name AS first_name,
#     COUNT(bookings.passenger_id) AS nb_bookings
# FROM passengers
# JOIN bookings ON bookings.passenger_id = passengers.passenger_id
# WHERE COUNT(bookings.passenger_id) > 1
# ': no such column: passengers.passenger_id

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name,
    passengers.first_name AS first_name,
    COUNT(bookings.passenger_id) AS nb_bookings
FROM passengers
JOIN bookings ON bookings.passenger_id = passengers.id
WHERE COUNT(bookings.passenger_id) > 1
""")
display(result)

assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
assert all(result['nb_bookings'] >= 2)
print("Exercice validé !")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: misuse of aggregate: COUNT()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 result = query("""
#       2 SELECT
#       3     passengers.last_name AS last_name,
#       4     passengers.first_name AS first_name,
#
# Cell In[18], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     passengers.last_name AS last_name,
#     passengers.first_name AS first_name,
#     COUNT(bookings.passenger_id) AS nb_bookings
# FROM passengers
# JOIN bookings ON bookings.passenger_id = passengers.id
# WHERE COUNT(bookings.passenger_id) > 1
# ': misuse of aggregate: COUNT()

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name,
    passengers.first_name AS first_name,
    COUNT(bookings.passenger_id) AS nb_bookings
FROM passengers
JOIN bookings ON bookings.passenger_id = passengers.id
HAVING COUNT(bookings.passenger_id) > 1
""")
display(result)

assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
assert all(result['nb_bookings'] >= 2)
print("Exercice validé !")
# Out:
#   last_name first_name  nb_bookings
# 0    Moreau      Lucas           19
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[47], line 12
#       8 HAVING COUNT(bookings.passenger_id) > 1
#       9 """)
#      10 display(result)
#      11
# ---> 12 assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
#      13 assert all(result['nb_bookings'] >= 2)
#      14 print("Exercice validé !")
#
# AssertionError: Il y a 5 passagers avec 2+ réservations, tu en as 1

# %%
result = query("""
SELECT 
    passengers.last_name AS last_name,
    passengers.first_name AS first_name,
    COUNT(bookings.id) AS nb_bookings
FROM passengers
JOIN bookings ON bookings.passenger_id = passengers.id
GROUP BY passengers.id, passengers.last_name, passengers.first_name
HAVING nb_bookings > 1;
""")
display(result)

assert len(result) == 5, f"Il y a 5 passagers avec 2+ réservations, tu en as {len(result)}"
assert all(result['nb_bookings'] >= 2)
print("Exercice validé !")
# Out:
#   last_name first_name  nb_bookings
# 0    Moreau      Lucas            2
# 1    Dubois       Emma            2
# 2     Smith       Liam            2
# 3   Bernard       Hugo            2
# 4    Martin      Alice            2
# Exercice validé !

# %%
uv add matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\mrobi\Cahier-Vacances-2026\.venv\Scripts\python.exe: No module named uv

# %%
# %pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\mrobi\Cahier-Vacances-2026\.venv\Scripts\python.exe: No module named pip

# %%
import matplotlib as mp

# %%
import matplotlib.pyplot as plt

result = query("""
SELECT 
    flights.destination,
    SUM(flights.price_eur) AS total_revenue,
    COUNT(bookings.id) AS nb_bookings
FROM bookings
JOIN flights ON bookings.flight_id 
WHERE bookings.status = 'confirmed'
GROUP BY flights.destination
HAVING COUNT(bookings.id) > 1
ORDER BY total_revenue DESC;
""")
display(result)

assert result.iloc[0]['destination'] == 'New York JFK', \
    f"La destination en tête devrait être New York JFK, tu as {result.iloc[0]['destination']}"

result.plot(kind='bar', x='destination', y='total_revenue', legend=False, color='steelblue')
plt.title("Chiffre d'affaires par destination (réservations confirmées, demande récurrente)")
plt.ylabel("Chiffre d'affaires (euros)")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 result = query("""
#       4 SELECT
#       5     flights.destination,
#       6     SUM(flights.price_eur) AS total_revenue,
#
# NameError: name 'query' is not defined

# %%
def query(sql):
    """Execute a SQL query and return the result as a pandas DataFrame."""
    return pd.read_sql_query(sql, conn)

print("=== PASSENGERS ===")
display(query("SELECT * FROM passengers LIMIT 5"))
print("=== FLIGHTS ===")
display(query("SELECT * FROM flights LIMIT 5"))
print("=== BOOKINGS ===")
display(query("SELECT * FROM bookings LIMIT 5"))
# Out:
# === PASSENGERS ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
#       3     return pd.read_sql_query(sql, conn)
#       4
#       5 print("=== PASSENGERS ===")
# ----> 6 display(query("SELECT * FROM passengers LIMIT 5"))
#       7 print("=== FLIGHTS ===")
#       8 display(query("SELECT * FROM flights LIMIT 5"))
#       9 print("=== BOOKINGS ===")
#
# Cell In[3], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# NameError: name 'pd' is not defined

# %%
import sqlite3
import pandas as pd

# %%
def query(sql):
    """Execute a SQL query and return the result as a pandas DataFrame."""
    return pd.read_sql_query(sql, conn)

# %%
import matplotlib.pyplot as plt

result = query("""
SELECT 
    flights.destination,
    SUM(flights.price_eur) AS total_revenue,
    COUNT(bookings.id) AS nb_bookings
FROM bookings
JOIN flights ON bookings.flight_id 
WHERE bookings.status = 'confirmed'
GROUP BY flights.destination
HAVING COUNT(bookings.id) > 1
ORDER BY total_revenue DESC;
""")
display(result)

assert result.iloc[0]['destination'] == 'New York JFK', \
    f"La destination en tête devrait être New York JFK, tu as {result.iloc[0]['destination']}"

result.plot(kind='bar', x='destination', y='total_revenue', legend=False, color='steelblue')
plt.title("Chiffre d'affaires par destination (réservations confirmées, demande récurrente)")
plt.ylabel("Chiffre d'affaires (euros)")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 result = query("""
#       4 SELECT
#       5     flights.destination,
#       6     SUM(flights.price_eur) AS total_revenue,
#
# Cell In[5], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# NameError: name 'conn' is not defined

# %%
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

# %%
import matplotlib.pyplot as plt

result = query("""
SELECT 
    flights.destination,
    SUM(flights.price_eur) AS total_revenue,
    COUNT(bookings.id) AS nb_bookings
FROM bookings
JOIN flights ON bookings.flight_id 
WHERE bookings.status = 'confirmed'
GROUP BY flights.destination
HAVING COUNT(bookings.id) > 1
ORDER BY total_revenue DESC;
""")
display(result)

assert result.iloc[0]['destination'] == 'New York JFK', \
    f"La destination en tête devrait être New York JFK, tu as {result.iloc[0]['destination']}"

result.plot(kind='bar', x='destination', y='total_revenue', legend=False, color='steelblue')
plt.title("Chiffre d'affaires par destination (réservations confirmées, demande récurrente)")
plt.ylabel("Chiffre d'affaires (euros)")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: bookings
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 result = query("""
#       4 SELECT
#       5     flights.destination,
#       6     SUM(flights.price_eur) AS total_revenue,
#
# Cell In[5], line 3, in query(sql)
#       1 def query(sql):
#       2     """Execute a SQL query and return the result as a pandas DataFrame."""
# ----> 3     return pd.read_sql_query(sql, conn)
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\Cahier-Vacances-2026\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     flights.destination,
#     SUM(flights.price_eur) AS total_revenue,
#     COUNT(bookings.id) AS nb_bookings
# FROM bookings
# JOIN flights ON bookings.flight_id
# WHERE bookings.status = 'confirmed'
# GROUP BY flights.destination
# HAVING COUNT(bookings.id) > 1
# ORDER BY total_revenue DESC;
# ': no such table: bookings

# %%
cursor.execute("""
CREATE TABLE passengers (
    id          INTEGER PRIMARY KEY,
    first_name  TEXT NOT NULL,
    last_name   TEXT NOT NULL,
    email       TEXT UNIQUE,
    nationality TEXT
);
""")

# %%
passengers_data = [
    (1, 'Lucas',   'Moreau',   'lucas.moreau@email.fr',    'Française'),
    (2, 'Emma',    'Dubois',   'emma.dubois@email.fr',     'Française'),
    (3, 'Noah',    'Leroy',    'noah.leroy@email.fr',      'Française'),
    (4, 'Sofia',   'Rossi',    'sofia.rossi@email.it',     'Italienne'),
    (5, 'Liam',    'Smith',    'liam.smith@email.uk',      'Britannique'),
    (6, 'Mia',     'Müller',   'mia.muller@email.de',      'Allemande'),
    (7, 'Hugo',    'Bernard',  'hugo.bernard@email.fr',    'Française'),
    (8, 'Camille', 'Thomas',   'camille.thomas@email.fr',  'Française'),
    (9, 'Alice',   'Martin',   'alice.martin@email.fr',    'Française'),
    (10,'Carlos',  'Garcia',   'carlos.garcia@email.es',   'Espagnole'),
    (11,'Jade',    'Petit',    'jade.petit@email.fr',      'Française'),
    (12,'Omar',    'Hassan',   'omar.hassan@email.ma',     'Marocaine'),
    (13,'Elena',   'Popescu',  'elena.popescu@email.ro',   'Roumaine'),
    (14,'Antoine', 'Garnier',  'antoine.garnier@email.fr', 'Française'),
    (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
# Out:
#   Cell In[10], line 16
#     (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
#                                                                         ^
# _IncompleteInputError: incomplete input

# %%
passengers_data = [
    (1, 'Lucas',   'Moreau',   'lucas.moreau@email.fr',    'Française'),
    (2, 'Emma',    'Dubois',   'emma.dubois@email.fr',     'Française'),
    (3, 'Noah',    'Leroy',    'noah.leroy@email.fr',      'Française'),
    (4, 'Sofia',   'Rossi',    'sofia.rossi@email.it',     'Italienne'),
    (5, 'Liam',    'Smith',    'liam.smith@email.uk',      'Britannique'),
    (6, 'Mia',     'Müller',   'mia.muller@email.de',      'Allemande'),
    (7, 'Hugo',    'Bernard',  'hugo.bernard@email.fr',    'Française'),
    (8, 'Camille', 'Thomas',   'camille.thomas@email.fr',  'Française'),
    (9, 'Alice',   'Martin',   'alice.martin@email.fr',    'Française'),
    (10,'Carlos',  'Garcia',   'carlos.garcia@email.es',   'Espagnole'),
    (11,'Jade',    'Petit',    'jade.petit@email.fr',      'Française'),
    (12,'Omar',    'Hassan',   'omar.hassan@email.ma',     'Marocaine'),
    (13,'Elena',   'Popescu',  'elena.popescu@email.ro',   'Roumaine'),
    (14,'Antoine', 'Garnier',  'antoine.garnier@email.fr', 'Française'),
    (15,'Yako',    'Tanaka',   'yuki.tanaka@email.jp',     'Japonaise'),
]

# %%
cursor.executemany("INSERT INTO passengers VALUES (?,?,?,?,?)", passengers_data)
conn.commit()

cursor.execute("SELECT COUNT(*) FROM passengers")
count = cursor.fetchone()[0]
assert count == 15, f"La table passengers devrait contenir 15 passagers, elle en a {count}"
print(f"Table passengers créée et remplie avec {count} passagers !")
# Out:
# Table passengers créée et remplie avec 15 passagers !

# %%
cursor.execute("""
CREATE TABLE flights ( 
    id INTEGER PRIMARY KEY,
    flight_number TEXT NOT NULL, 
    origin TEXT NOT NULL, 
    destination TEXT NOT NULL,
    departure_time TEXT NOT NULL,
    arrival_time TEXT NOT NULL,
    aircraft TEXT,
    capacity INTEGER,
    price_eur REAL
);
""")

# %%
flights_data = [
    (1,  'AF1234', 'Nice',      'Paris CDG',    '2026-07-01 07:00', '2026-07-01 08:30', 'Airbus A320', 180, 89.0),
    (2,  'AF1235', 'Paris CDG', 'Nice',          '2026-07-01 19:00', '2026-07-01 20:30', 'Airbus A320', 180, 95.0),
    (3,  'EZ4501', 'Nice',      'Londres',       '2026-07-02 06:30', '2026-07-02 08:15', 'Airbus A319', 156, 120.0),
    (4,  'EZ4502', 'Nice',      'Amsterdam',     '2026-07-02 09:00', '2026-07-02 11:30', 'Airbus A319', 156, 135.0),
    (5,  'VY6010', 'Nice',      'Barcelone',     '2026-07-03 11:00', '2026-07-03 12:45', 'Boeing 737',  189, 78.0),
    (6,  'AF5501', 'Nice',      'New York JFK',  '2026-07-04 13:00', '2026-07-04 22:30', 'Boeing 777',  350, 650.0),
    (7,  'LH2201', 'Nice',      'Francfort',     '2026-07-05 08:00', '2026-07-05 09:45', 'Airbus A320', 180, 112.0),
    (8,  'IB3301', 'Nice',      'Madrid',        '2026-07-05 14:00', '2026-07-05 16:00', 'Boeing 737',  189, 99.0),
    (9,  'AF1236', 'Nice',      'Paris CDG',     '2026-07-06 18:00', '2026-07-06 19:30', 'Airbus A320', 180, 105.0),
    (10, 'U24401', 'Nice',      'Athènes',       '2026-07-07 10:00', '2026-07-07 13:30', 'Boeing 737',  189, 145.0),
    (11, 'FR7701', 'Nice',      'Dublin',        '2026-07-08 07:30', '2026-07-08 10:00', 'Boeing 737',  189, 89.0),
    (12, 'AF1237', 'Paris CDG', 'Nice',          '2026-07-08 20:00', '2026-07-08 21:30', 'Airbus A321', 220, 88.0),
    (13, 'EZ4503', 'Nice',      'Berlin',        '2026-07-09 12:00', '2026-07-09 14:15', 'Airbus A319', 156, 118.0),
    (14, 'AF5502', 'Nice',      'New York JFK',  '2026-07-10 13:00', '2026-07-10 22:30', 'Boeing 777',  350, 680.0),
    (15, 'TK8801', 'Nice',      'Istanbul',      '2026-07-11 09:00', '2026-07-11 12:30', 'Boeing 737',  189, 160.0),
]

# %%
cursor.executemany("INSERT INTO flights VALUES (?,?,?,?,?,?,?,?,?)", flights_data)
conn.commit()

cursor.execute("PRAGMA table_info(flights)")
columns = cursor.fetchall()
schema = {col[1]: col[2] for col in columns}
expected_schema = {
    'id': 'INTEGER', 'flight_number': 'TEXT', 'origin': 'TEXT', 'destination': 'TEXT',
    'departure_time': 'TEXT', 'arrival_time': 'TEXT', 'aircraft': 'TEXT',
    'capacity': 'INTEGER', 'price_eur': 'REAL',
}
assert schema == expected_schema, f"Le schéma ne correspond pas. Attendu : {expected_schema}, obtenu : {schema}"

not_null_columns = {col[1] for col in columns if col[3] == 1}
expected_not_null = {'flight_number', 'origin', 'destination', 'departure_time', 'arrival_time'}
assert not_null_columns == expected_not_null, \
    f"Les colonnes NOT NULL attendues sont {expected_not_null}, tu as : {not_null_columns}"

cursor.execute("SELECT COUNT(*) FROM flights")
count = cursor.fetchone()[0]
assert count == 15, f"La table flights devrait contenir 15 vols, elle en a {count}"
print(f"Table flights créée et remplie avec {count} vols, exercice validé !")
# Out:
# Table flights créée et remplie avec 15 vols, exercice validé !

# %%
cursor.execute("""
CREATE TABLE bookings (
    id INTEGER PRIMARY KEY,
    passenger_id INTEGER REFERENCES passengers(id),
    flight_id INTEGER REFERENCES flights(id),
    booking_date TEXT,
    seat_class TEXT CHECK (seat_class IN ('economy', 'business', 'first')),
    seat_number TEXT,
    status TEXT CHECK (status IN ('confirmed', 'cancelled', 'pending'))
);
""")

# %%
bookings_data = [
    (1,  1,  1,  '2026-06-01', 'economy',  '14A', 'confirmed'),
    (2,  2,  1,  '2026-06-02', 'business', '2C',  'confirmed'),
    (4,  4,  5,  '2026-06-05', 'economy',  '18C', 'confirmed'),
    (5,  5,  3,  '2026-06-06', 'business', '1A',  'confirmed'),
    (6,  6,  7,  '2026-06-07', 'economy',  '31D', 'confirmed'),
    (7,  7,  6,  '2026-06-08', 'first',    '1A',  'confirmed'),
    (8,  8,  6,  '2026-06-09', 'business', '3B',  'confirmed'),
    (9,  9,  9,  '2026-06-10', 'economy',  '25A', 'confirmed'),
    (10, 10, 5,  '2026-06-11', 'economy',  '17B', 'cancelled'),
    (11, 11, 10, '2026-06-12', 'economy',  '8C',  'confirmed'),
    (12, 12, 15, '2026-06-13', 'economy',  '11A', 'confirmed'),
    (13, 13, 4,  '2026-06-14', 'economy',  '29B', 'pending'),
    (14, 14, 2,  '2026-06-15', 'business', '4A',  'confirmed'),
    (15, 15, 6,  '2026-06-16', 'first',    '2A',  'confirmed'),
    (16, 1,  9,  '2026-06-17', 'economy',  '33C', 'confirmed'),
    (17, 2,  10, '2026-06-18', 'economy',  '15A', 'cancelled'),
    (18, 5,  6,  '2026-06-19', 'business', '5B',  'confirmed'),
    (19, 7,  14, '2026-06-20', 'first',    '1B',  'confirmed'),
    (20, 9,  11, '2026-06-21', 'economy',  '22D', 'confirmed'),
]

# %%
cursor.executemany("INSERT INTO bookings VALUES (?,?,?,?,?,?,?)", bookings_data)
conn.commit()

cursor.execute("PRAGMA table_info(bookings)")
schema = {col[1]: col[2] for col in cursor.fetchall()}
expected_schema = {
    'id': 'INTEGER', 'passenger_id': 'INTEGER', 'flight_id': 'INTEGER',
    'booking_date': 'TEXT', 'seat_class': 'TEXT', 'seat_number': 'TEXT', 'status': 'TEXT',
}
assert schema == expected_schema, f"Le schéma ne correspond pas. Attendu : {expected_schema}, obtenu : {schema}"

try:
    cursor.execute("INSERT INTO bookings VALUES (999, 1, 1, '2026-06-30', 'premium', '1A', 'confirmed')")
    raise AssertionError("La contrainte CHECK sur seat_class ne fonctionne pas : 'premium' a été accepté")
except sqlite3.IntegrityError:
    pass

cursor.execute("SELECT COUNT(*) FROM bookings")
count = cursor.fetchone()[0]
assert count == 19, f"La table bookings devrait contenir 19 réservations, elle en a {count}"

print("Base de données complète, exercice validé !")
print(f"  {len(passengers_data)} passagers")
print(f"  {len(flights_data)} vols")
print(f"  {len(bookings_data)} réservations")
# Out:
# Base de données complète, exercice validé !
#   15 passagers
#   15 vols
#   19 réservations

# %%
import matplotlib.pyplot as plt

result = query("""
SELECT 
    flights.destination,
    SUM(flights.price_eur) AS total_revenue,
    COUNT(bookings.id) AS nb_bookings
FROM bookings
JOIN flights ON bookings.flight_id 
WHERE bookings.status = 'confirmed'
GROUP BY flights.destination
HAVING COUNT(bookings.id) > 1
ORDER BY total_revenue DESC;
""")
display(result)

assert result.iloc[0]['destination'] == 'New York JFK', \
    f"La destination en tête devrait être New York JFK, tu as {result.iloc[0]['destination']}"

result.plot(kind='bar', x='destination', y='total_revenue', legend=False, color='steelblue')
plt.title("Chiffre d'affaires par destination (réservations confirmées, demande récurrente)")
plt.ylabel("Chiffre d'affaires (euros)")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
#      destination  total_revenue  nb_bookings
# 0   New York JFK        21280.0           32
# 1      Paris CDG         3104.0           32
# 2           Nice         2928.0           32
# 3       Istanbul         2560.0           16
# 4        Athènes         2320.0           16
# 5      Amsterdam         2160.0           16
# 6        Londres         1920.0           16
# 7         Berlin         1888.0           16
# 8      Francfort         1792.0           16
# 9         Madrid         1584.0           16
# 10        Dublin         1424.0           16
# 11     Barcelone         1248.0           16
